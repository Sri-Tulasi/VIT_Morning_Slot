# %%
*******statistics***
1.Descriptive statistics are for describing the properties of sample and population data (what has happened)
2.Inferential statistics use those properties to test hypotheses, reach conclusions, and make predictions (what can you expect).


Use of Statistics in Machine Learning::::

*Asking questions about the data
*Cleaning and preprocessing the data
*Selecting the right features
*Model evaluation
*Model prediction


1.Population and sample
:::::Population::::
In statistics, the population comprises all observations (data points) about the subject under study.
:::::sample::::
In statistics, a sample is a subset of the population. It is a small portion of the total observed population.


2.Measures of Central Tendency
	1.Mean
	2.Median
	3.Mode
3.Variance and Standard Deviation
:::::Standard Deviation::::
The Standard Deviation is a measure of how spread out our data is.
;;;;;Variance:::
Variance measures the spread between all data points in a dataset.

::;:Covariance::::
Covariance finds the direction of the relationship between two data points. It finds whether two data points are directly or inversely proportional.

# %%
1.univariate 
2.bivariate
3.multi variate

# %%
1.univariate --only one variable at time----histograms,bar charts,pie charts,boxplots  -----categorical or numerical
2.Bivariate--two varaibles---categorical or numerical

numerical vs numerical  -scatterplot
numerical vs categorical ---ANOVA 
categorical vs categorical ----Chi squared error test

3.multi variate analysis---many variables
clustering anlysis
principal component analysis PCA
Multi correspondence analysis

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### Line Graph

# %%
x=[1,2,3,5,6,89,8]
y=[3,5,6,8,9,4,9]

# %%
plt.plot(x,y)

# %%
x=np.linspace(1,15,10)
y=x**2

# %%
x
# Out:
# array([ 1.        ,  2.55555556,  4.11111111,  5.66666667,  7.22222222,
#         8.77777778, 10.33333333, 11.88888889, 13.44444444, 15.        ])

# %%
y
# Out:
# array([  1.        ,   6.5308642 ,  16.90123457,  32.11111111,
#         52.16049383,  77.04938272, 106.77777778, 141.34567901,
#        180.75308642, 225.        ])

# %%
plt.plot(x,y,'b->')

# %% [markdown]
# Draw a line in a diagram from position (1, 3) to (2, 8) then to (6, 1) and finally to position (8, 10):

# %%
x=[1,2,6,8]
y=[3,8,1,10]
plt.plot(x,y,'b-*')

# %%
plt.plot(x,y,'b-*',ms=20)

# %%
plt.plot(x,y,'b-*',ms=20,mec='r')

# %%
plt.plot(x,y,'b-*',ms=20,mec='r')
plt.grid()

# %% [markdown]
# ### Subplots

# %%
x=np.linspace(1,15,10)
y=x**2

# %%
plt.subplot(2,2,1)
plt.plot(x,y,'b--')
plt.subplot(2,2,2)
plt.plot(x,y,'r*')
plt.subplot(2,2,3)
plt.plot(x,y,'g*')
plt.subplot(2,2,4)
plt.plot(x,y,'r>')

# %%
fig=plt.figure()
ax1=fig.add_axes([0.1,0.1,0.8,0.8])
ax2=fig.add_axes([0.2,0.5,0.4,0.3])
#[left,bottom,width,height]
ax1.plot(x,y)

ax2.plot(y,x)

# %% [markdown]
# ## Scatter Plot

# %%
plt.scatter(x,y)
plt.xlabel("x axis")
plt.ylabel("y axis")
# Out:
# Text(0, 0.5, 'y axis')

# %% [markdown]
# ### Compare two plots

# %%
import matplotlib.pyplot as plt
import numpy as np
#day one, the age and speed of 7 cars:
x = np.array([5,7,8,7,2,17,2])
y = np.array([99,86,87,88,111,86,103])
plt.scatter(x, y, color = 'hotpink')
#day two, the age and speed of 13 cars:
x = np.array([2,2,8,1,15,8,12])
y = np.array([100,105,84,105,90,93,97])
plt.scatter(x, y, color = '#88c999')

plt.show()

# %% [markdown]
# ### Bar Chart

# %%
x=np.array(["A","B","C","D"])
y=np.array([3,8,1,10])
plt.bar(x,y)
# Out:
# <BarContainer object of 4 artists>

# %%
plt.barh(x,y)
# Out:
# <BarContainer object of 4 artists>

# %%
plt.barh(x,y,color="red")
# Out:
# <BarContainer object of 4 artists>

# %%
plt.bar(x,y,width=0.1)
# Out:
# <BarContainer object of 4 artists>

# %% [markdown]
# ### Histogram

# %%
x=np.random.normal(170,10,250)

# %%
x
# Out:
# array([175.73222576, 171.29334738, 185.8413135 , 164.70717114,
#        162.76792527, 179.69965011, 170.48333737, 172.26450252,
#        160.07003941, 173.39921416, 164.46499408, 179.35380669,
#        172.46106208, 164.05358971, 163.78119012, 183.90664682,
#        167.96757267, 189.10719938, 175.46207541, 176.74051888,
#        160.23749734, 158.69278758, 148.43207565, 195.34060742,
#        175.74080201, 173.63872646, 171.34495362, 181.66055099,
#        175.66548611, 197.86388708, 172.20971535, 170.96902211,
#        165.26953296, 182.49456088, 184.5592355 , 165.29198658,
#        166.29758766, 167.45821049, 162.48757038, 158.59985783,
#        167.24578566, 172.76533077, 175.7510502 , 165.07159893,
#        175.3287576 , 176.65007201, 179.49004627, 170.67117622,
#        159.26481123, 176.1139669 , 164.59430791, 180.39835053,
#        174.78389976, 174.18447652, 164.56963581, 169.91748027,
#        174.84500255, 167.78001945, 170.68008413, 172.14614355,
#        173.23153924, 167.45434636, 171.04884048, 182.0562881 ,
#        149.5536677 , 154.91851935, 172.65839096, 177.49400109,
#        158.06709823, 161.28276736, 166.51113194, 170.27836547,
#        154.86631001, 178.83099183, 164.42820874, 170.98951971,
#        165.5341841 , 165.45100491, 172.7897585 , 174.78998623,
#        179.36747453, 180.70384817, 165.79795774, 182.88944798,
#        161.65559542, 177.36393646, 153.24793898, 181.34446512,
#        181.56154197, 184.91991077, 179.1076548 , 172.79562558,
#        152.71291304, 170.33728609, 197.13214884, 162.20690221,
#        168.8333203 , 162.9462518 , 182.12031795, 169.13742354,
#        160.77341217, 168.44847784, 158.93436188, 158.74277764,
#        172.87207841, 162.49464348, 140.71053875, 149.6598245 ,
#        155.97525606, 152.18735376, 175.60732665, 169.14662999,
#        166.99400963, 165.68915821, 166.72197563, 155.21496998,
#        171.34584238, 172.07112373, 167.77288415, 170.77371503,
#        168.49432934, 183.23184409, 171.70120738, 165.32250295,
#        183.29796617, 173.84352768, 159.47725419, 176.29486143,
#        167.72554087, 174.13130026, 154.64891462, 171.5149109 ,
#        158.85161696, 170.07022128, 162.55497508, 165.69542865,
#        167.56337596, 162.24166267, 175.70325236, 171.45684014,
#        158.9571663 , 178.06525158, 164.61959358, 163.45193199,
#        160.36864948, 179.94208507, 165.48646306, 181.93169571,
#        175.82103174, 181.77077451, 181.6913093 , 170.07158771,
#        186.53185855, 164.08774772, 181.08125448, 164.65179494,
#        174.21626615, 170.13179151, 174.5656358 , 174.59972991,
#        178.02773817, 179.11764402, 149.54162039, 168.66654192,
#        160.8490107 , 174.14643042, 172.70703134, 191.22477474,
#        174.28677274, 174.15685765, 178.13126866, 163.84556419,
#        169.16070746, 178.92396323, 186.86550992, 163.58408959,
#        161.14475847, 177.68537426, 159.59379091, 169.21920843,
#        170.67152929, 157.02567386, 158.07866962, 165.19145259,
#        175.79011549, 176.0470605 , 170.04997534, 180.04959159,
#        171.88258297, 161.11129381, 156.4116822 , 153.00697009,
#        174.37271395, 172.83429948, 161.26428061, 175.13872691,
#        176.06115202, 168.60558719, 181.95504131, 164.73967325,
#        192.38080543, 166.83336627, 185.77703952, 161.28473876,
#        181.14261256, 166.20937333, 199.51623025, 160.62354289,
#        178.00359624, 155.15335937, 184.75026604, 166.58506709,
#        176.84076693, 172.52549884, 178.3311129 , 143.00483055,
#        170.23865166, 165.05038635, 176.38805309, 177.96043338,
#        171.89953463, 189.27072274, 176.44642409, 161.45937706,
#        172.0816979 , 177.02368488, 177.02781565, 164.55848257,
#        172.14654991, 168.19362958, 180.10224895, 162.89613019,
#        165.80206004, 157.23024036, 156.40054032, 166.15576519,
#        169.91415955, 175.22522212, 173.19654308, 181.67882385,
#        161.04511762, 174.6262361 , 172.84074964, 174.4969117 ,
#        175.32581411, 177.90466859, 178.50291843, 153.30393128,
#        157.52764937, 172.3795052 ])

# %%
plt.hist(x)
plt.show()

# %% [markdown]
# ### Pie Charts

# %%
import matplotlib.pyplot as plt
labels=["php","pyhton","java","c"]
numbers=[75,70,80,60]
fig=plt.figure()
axes1=fig.add_axes([0.1,0.1,0.8,0.8])  #[left,bottom,width,height]
axes1.pie(numbers,labels=labels,autopct="%0.2f%%",colors=["orange","pink","green","blue"])
axes1.legend()

# %%
#=["php","pyhton","java","c"]
Explode=[0.5,0,0,0.2]
plt.pie(numbers,labels=labels,explode=Explode)
# Out:
# ([<matplotlib.patches.Wedge at 0x1bd37b69580>,
#   <matplotlib.patches.Wedge at 0x1bd37cf6c10>,
#   <matplotlib.patches.Wedge at 0x1bd37ef5940>,
#   <matplotlib.patches.Wedge at 0x1bd37ef5700>],
#  [Text(1.0836504797969189, 1.1771582891165944, 'php'),
#   Text(-0.8295173176268907, 0.7224271726320158, 'pyhton'),
#   Text(-0.6514587095050077, -0.8863416665203493, 'java'),
#   Text(1.0258827330394034, -0.7984764355017653, 'c')])

# %% [markdown]
# # Seaborn

# %%
pip install seaborn

# %%
import seaborn as sns

# %%
print(sns.get_dataset_names())
# Out:
# C:\Users\Tulasi\anaconda3\lib\site-packages\seaborn\utils.py:384: GuessedAtParserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 384 of the file C:\Users\Tulasi\anaconda3\lib\site-packages\seaborn\utils.py. To get rid of this warning, pass the additional argument 'features="lxml"' to the BeautifulSoup constructor.
#
#   gh_list = BeautifulSoup(http)
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'dowjones', 'exercise', 'flights', 'fmri', 'geyser', 'glue', 'healthexp', 'iris', 'mpg', 'penguins', 'planets', 'seaice', 'taxis', 'tips', 'titanic']

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-26-3164610e0ce5> in <module>
# ----> 1 sns.download("tips")
#
# AttributeError: module 'seaborn' has no attribute 'download'

# %%
df=sns.load_dataset('tips')

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.__version__
# Out:
# '0.10.1'

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.3 KB

# %%
df.head(5)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.scatterplot(x="total_bill",y="tip",data=df)

# %%
Inference:from the plot we can say that as bill amount increases tip is alos increasing

# %%
sns.scatterplot(x="size",y="tip",data=df)

# %%
sns.lineplot(x="size",y="total_bill",data=df,ci=None)

# %%
sns.distplot(df["tip"])

# %%
sns.relplot(x="total_bill",y="tip",data=df,hue="day")

# %%
df["day"].value_counts()
# Out:
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: day, dtype: int64

# %%
sns.barplot(data=df,x="day",y="tip",ci=None)

# %%
sns.barplot(data=df,x="sex",y="tip",hue="day")

# %%
sns.countplot(x="sex",data=df)

# %%
sns.jointplot(x="total_bill",y="tip",data=df)

# %%
age
1 2 7 9 2 34 37 200
1 2 2 7 9 34 37 200
Q1=2 =LOWER QUARTILE

Median ==9+7/2=8 Q2

Q3=35.5=UPEER QUARTILLE

IQR=INTER QUARTILE RANGE=Q3-Q1

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
sns.boxplot(x="day",y="total_bill",data=df)

# %%
Correlation

positive correlation
negative correlation
neutral correlation

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
corr=df.corr()
corr
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
>0.5 is highly correlated
<0.5 is less correlated

# %%
sns.heatmap(corr,annot=True,cmap="YlGnBu")
